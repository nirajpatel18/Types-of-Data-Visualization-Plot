# %% [markdown]
# # pie chart

# %%
from matplotlib import pyplot as plt
values = [62, 142,90,200] 
labels = ['Travel', 'contact', 'household contact', 'unknown'] 
plt.title('Transmission\n')
plt.pie(values,labels=labels, autopct= '%2.2f%%')
plt.show()
